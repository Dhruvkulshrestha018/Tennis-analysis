# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SYklrA4YyFz7Q42IrAzE")
project = rf.workspace("tenniscv-yywpa").project("tennis-court-keypoints")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (1.1.50)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (2024.12.14)
# Requirement already satisfied: idna==3.7 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/YOLOproject/lib/python3.12/site-packages (from requests->roboflow) (3.4.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-court-keypoints-1 to yolov11:: 100%|██████████| 15807/15807 [00:05<00:00, 3146.04it/s]
# Extracting Dataset Version Zip to tennis-court-keypoints-1 in yolov11:: 100%|██████████| 610/610 [00:00<00:00, 6623.29it/s]

# %%
import shutil
